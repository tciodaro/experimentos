# %%
import os
import sys
import matplotlib.pyplot as plt


current_dir = os.getcwd()
if f"{current_dir}/../" not in sys.path:
    sys.path.append(f"{current_dir}/../")

    
# %matplotlib inline
# %load_ext autoreload
# %autoreload 0
import numpy as np
import copy

from Swarm import Problem_Antenna, PSO
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Load Data

# %%
problem = Problem_Antenna.Problem(f"{current_dir}/../Data/")
#problem.load_test() # for testing
problem.load()

# %% [markdown]
# # Training Parameters

# %%
swarm_dim = problem.get_problem_dim()
swarm_min, swarm_max = problem.get_solution_limits()
ninit = 1
init_costs = np.zeros(ninit)
psoArgs = {
    'nswarm': 20,
    'swarm_dim': swarm_dim,
    'epochs': 50,
    'chi': -1, #0.729,
    'rate_cog': 2.05,
    'rate_soc': 2.05,
    'K': 10.0,
    'Wup': 1.2,
    'Wlo': 0.5,
    'Wstep': 50,
    'swarm_max': swarm_max,
    'swarm_min': swarm_min,
    'speed_lim': -1,
    'trn_nproc': 2
}

best_pso = None
best_cost = 1e20
for iinit in range(ninit):
    print('Initialization: ', iinit)
    mypso = PSO.PSO(psoArgs)
    mypso.cost_func = problem.cost_function
    mypso.initialize()
    (solution_idx, sol_cost) = mypso.train()
    print("\tSolution found with cost: ", sol_cost)
    init_costs[iinit] = sol_cost
    if best_cost > sol_cost:
        best_cost = sol_cost
        best_pso = copy.deepcopy(mypso)
mypso = best_pso
opt_solution = mypso.swarm_best[-1]
# Out:
# Initialization:  0
# PSO Training started...
# done (707.94 s)
# 	Time epochs: 694.84 s
# 	Time cost F: 694.83 s
# 	Solution found with cost:  17700.0

# %% [markdown]
# # Plot Training Aspects

# %%
plt.figure()
plt.plot(mypso.global_diversity, 'k', lw=2)
plt.grid(True)
plt.xlabel('Epochs')
plt.ylabel('Swarm Diversity')
plt.figure()
plt.plot(mypso.diversity, lw=2)
plt.grid(True)
plt.xlabel('Epochs')
plt.ylabel('Dimension Diversity')
plt.figure()
plt.plot(mypso.fitness)
plt.grid(True)
plt.xlabel('Epochs')
plt.ylabel('Swarm Best Fitness')
# Out:
# Text(0, 0.5, 'Swarm Best Fitness')

# %% [markdown]
# # Plot Solution On Map

# %%
mypso.cost_func(opt_solution)
# Out:
# 17700.0

# %%
# PLOT MAP
plt.figure(figsize=(12,8))
problem.plot_map()
ax = plt.axis()
# PLOT BASIC PSO SOLUTION
problem.plot_solution(opt_solution, 'b')
plt.axis(ax);

# %% [markdown]
# # Animated GIF (must have imagemagick installed)

# %%
problem.plot_swarm_evolution(mypso.swarm_best, 'swarm_evolution_ipynb.gif')
# Out:
# MovieWriter imagemagick unavailable; using Pillow instead.
